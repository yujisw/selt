# %%
import pandas as pd
import numpy as np
import os
import requests
import re

# %%
data_dir = '../bert_ner/model_test/'
os.listdir(data_dir)
# Out:
# ['test_predictions.txt',
#  'special_tokens_map.json',
#  'test_results.txt',
#  'added_tokens.json',
#  'pytorch_model.bin',
#  'vocab.txt',
#  'tokenizer_config.json',
#  'eval_results.txt',
#  'config.json',
#  'training_args.bin']

# %%
df_test_result = pd.read_csv(os.path.join(data_dir,"test_predictions.txt"), sep=' ', names=['形態素', 'IOB2'])
df_test_result
# Out:
#            形態素 IOB2
# 0       [NULL]    O
# 1           平成    O
# 2           三十    O
# 3            年    O
# 4            七    O
# ...        ...  ...
# 209857       時    O
# 209858      五十    O
# 209859       九    O
# 209860       分    O
# 209861      散会    O
#
# [209862 rows x 2 columns]

# %%
IOB2_string = ''.join(df_test_result['IOB2'].values)

# %%
IOB2_string = IOB2_string.replace('BB','BI').replace('OBO','OOO').replace('OIO','OOO')

# %%
matches = re.finditer(r'O[I]+', IOB2_string)
IOB2_list = list(IOB2_string)
for m in matches:
    print(m.span()[0], IOB2_list[m.span()[0]+1])
    IOB2_list[m.span()[0]+1] = 'B'
# Out:
# 12332 I
# 14532 I
# 24477 I
# 72163 I

# %%
IOB2_list[12332+1]
# Out:
# 'B'

# %%
df_test_result['IOB2'] = pd.Series(IOB2_list)

# %%
p = re.compile('[\u3041-\u309F]+') #平仮名かどうか
special_tokens = ['、', '。', '　', ' ', '・', '[SPACE]', '[BAR]', '[NULL]', '[LBAR]', '[SEP]']
USELESS_or_not = [True if ((p.fullmatch(w) is not None) or (w in special_tokens)) else False for w in list(df_test_result['形態素'].values)]

# %%
sum(USELESS_or_not)
# Out:
# 135525

# %%
USELESS_B = df_test_result[(df_test_result['IOB2']=='B') & USELESS_or_not]

# %%
for index, item in USELESS_B.iterrows():
    df_test_result['IOB2'][index] = 'O'
    df_test_result['IOB2'][index+1] = 'B'

# %%
USELESS_E = df_test_result[((df_test_result['IOB2']=='I') * (df_test_result['IOB2']!='I').shift(periods=-1, fill_value=False)) & USELESS_or_not]
# Out:
# /home/naraki/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
for index, item in USELESS_E.iterrows():
    df_test_result['IOB2'][index] = 'O'

# %%
mention_list = []
mention_len = 0
mention_name = ''
for index,item in df_test_result.iterrows():
#     print(index, item['形態素'], item['IOB2'])
    if item['IOB2']=='O':
        if mention_len>0:
            for i in range(mention_len):
                mention_list.append(mention_name)
            mention_len=0
            mention_name=''
        mention_list.append(np.nan)
    elif item['IOB2']=='B':
        if mention_len>0:
            for i in range(mention_len):
                mention_list.append(mention_name)

        mention_len=1
        mention_name = item['形態素']
    elif item['IOB2']=='I':
        mention_len += 1
        mention_name = mention_name + item['形態素']
# mention_list

# %%
df_test_result['メンション'] = pd.Series(mention_list)
df_test_result[:10]
# Out:
#       形態素 IOB2 メンション
# 0  [NULL]    O   NaN
# 1      平成    O   NaN
# 2      三十    O   NaN
# 3       年    O   NaN
# 4       七    O   NaN
# 5       月    O   NaN
# 6       十    O   NaN
# 7       八    O   NaN
# 8       日    O   NaN
# 9       （    O   NaN

# %%
def judge_mention_by_end(mention):
    if type(mention) is not str:
        return False
    end_list = [
        '法',
        '法案',
        '法制',
        'に関する法律',
        'に関する法律案',
        'の一部を改正する法律案',
        '改正案',
        '法律',
    ]
    for end in end_list:
        if mention.endswith(end):
            return True
    return False

# %%
mention_list = list(df_test_result['メンション'].values)
fake_mention_or_not = [not judge_mention_by_end(mention) for mention in mention_list]
fake_mention = df_test_result[(df_test_result['IOB2']!='O') & fake_mention_or_not]

for index, item in fake_mention.iterrows():
    df_test_result['IOB2'][index] = 'O'
    df_test_result['メンション'][index] = np.nan

# %%
from wikipedia2vec import Wikipedia2Vec
pretrained_emb_path = '../pretrained_embedding/jawiki_20180420_300d.pkl'
wiki2vec = Wikipedia2Vec.load(pretrained_emb_path)

# %%
wiki2vec.get_entity('リゾート法') is None
wiki2vec.get_entity('リゾート法').title
# Out:
# '総合保養地域整備法'

# %%
def get_official_name(mention_name):
    e = wiki2vec.get_entity(mention_name)
    if e is None:
        e_dash = None
        if mention_name.endswith('案'):
            e_dash = wiki2vec.get_entity(mention_name[:-1])
        elif mention_name.endswith('法'):
            e_dash = wiki2vec.get_entity(mention_name+'案')
        if e_dash is None:
            return None
        return e_dash.title
    return e.title

# %%
n = '総合保養地域整備法'
n[:-1]
# Out:
# '総合保養地域整備'

# %%
def get_url_from_title(title):
    S = requests.Session()
    URL = "https://ja.wikipedia.org/w/api.php"
    PARAMS = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "info",
        "inprop": "url"
    }
    R = S.get(url=URL, params=PARAMS)
    DATA = R.json()

    PAGES = DATA["query"]["pages"]
    
    for k, v in PAGES.items():
        return v["fullurl"]

# %%
ZEN = "".join(chr(0xff01 + i) for i in range(94))
HAN = "".join(chr(0x21 + i) for i in range(94))

ZEN2HAN = str.maketrans(ZEN, HAN)

title_list = []
url_list = []
for index,item in df_test_result.iterrows():
    if index%10000==0:
        print(index, item['形態素'], item['IOB2'])
    mention_name = item['メンション']
    if type(mention_name) is not str:
        title_list.append(np.nan)
        url_list.append(np.nan)
    else:
        official_name = get_official_name(mention_name.translate(ZEN2HAN))
        if official_name is None:
            title_list.append(np.nan)
            url_list.append(np.nan)
        else:
            title_list.append(official_name)
            url_list.append(get_url_from_title(official_name))

df_test_result['wikipediaタイトル'] = pd.Series(title_list)
df_test_result['wikipediaページ'] = pd.Series(url_list)
df_test_result[:20]
# Out:
# 0 [NULL] O
# 10000 三 O
# 20000 下げ O
# 30000 ませ O
# 40000 [SPACE] O
# 50000 に O
# 60000 なら O
# 70000 の O
# 80000 交渉 O
# 90000 もらい O
# 100000 、 O
# 110000 伺い O
# 120000 人材 O
# 130000 もらっ O
# 140000 て O
# 150000 し O
# 160000 、 O
# 170000 総務 O
# 180000 退席 O
# 190000 ます O
# 200000 、 O
#         形態素 IOB2 メンション wikipediaタイトル wikipediaページ
# 0    [NULL]    O   NaN           NaN          NaN
# 1        平成    O   NaN           NaN          NaN
# 2        三十    O   NaN           NaN          NaN
# 3         年    O   NaN           NaN          NaN
# 4         七    O   NaN           NaN          NaN
# 5         月    O   NaN           NaN          NaN
# 6         十    O   NaN           NaN          NaN
# 7         八    O   NaN           NaN          NaN
# 8         日    O   NaN           NaN          NaN
# 9         （    O   NaN           NaN          NaN
# 10       水曜    O   NaN           NaN          NaN
# 11        日    O   NaN           NaN          NaN
# 12        ）    O   NaN           NaN          NaN
# 13  [SPACE]    O   NaN           NaN          NaN
# 14  [SPACE]    O   NaN           NaN          NaN
# 15  [SPACE]    O   NaN           NaN          NaN
# 16       午前    O   NaN           NaN          NaN
# 17        十    O   NaN           NaN          NaN
# 18        時    O   NaN           NaN          NaN
# 19        一    O   NaN           NaN          NaN

# %%
get_official_name('IR法案')
# Out:
# '特定複合観光施設区域の整備の推進に関する法律'

# %%
get_official_name('ＩＲ法案'.translate(ZEN2HAN))
# Out:
# '特定複合観光施設区域の整備の推進に関する法律'

# %%
pd.set_option('display.max_rows', 1000)
df_test_result[df_test_result['IOB2']=='B']
# Out:
#          形態素 IOB2                                   メンション  \
# 53        健康    B                        健康増進法の一部を改正する法律案
# 78        北方    B  北方領土問題等の解決の促進のための特別措置に関する法律の一部を改正する法律案
# 113       北方    B     北方地域旧漁業権者等に対する特別措置に関する法律の一部を改正する法律案
# 635       施設    B                                施設区域整備法案
# 642       ＩＲ    B                                  ＩＲ整備法案
# 656      カジノ    B                                   カジノ法案
# 1184     カジノ    B                                   カジノ法案
# 1194     カジノ    B                                   カジノ法案
# 2045      ＩＲ    B                                   ＩＲ整備法
# 2093      ＩＲ    B                                    ＩＲ法案
# 2437      ＩＲ    B                                  ＩＲ整備法案
# 3420      施設    B                                施設区域整備法案
# 3427      ＩＲ    B                                    ＩＲ法案
# 4793     カジノ    B                                   カジノ法案
# 5195     カジノ    B                                   カジノ法案
# 5473     カジノ    B                                   カジノ法案
# 5707      推進    B                                    推進法案
# 5720      整備    B                                    整備法案
# 6332     カジノ    B                                    カジノ法
# 6336      特定    B                            特定複合観光施設整備法案
# 7348     カジノ    B                                 カジノ推進法案
# 7486      ＩＲ    B                                    ＩＲ法案
# 9224      賭博    B                                   賭博解禁法
# 9616     カジノ    B                                   カジノ法案
# 9842      売国    B                                    売国法案
# 10276     貸金    B                                    貸金業法
# 10431    カジノ    B                                  カジノ推進法
# 10563    カジノ    B                                   カジノ法案
# 10746    カジノ    B                                   カジノ法案
# 11772     健康    B                        健康増進法の一部を改正する法律案
# 12008     健康    B                        健康増進法の一部を改正する法律案
# 12333     増進    B                          増進法の一部を改正する法律案
# 14139     北方    B  北方領土問題等の解決の促進のための特別措置に関する法律の一部を改正する法律案
# 14167     北方    B     北方地域旧漁業権者等に対する特別措置に関する法律の一部を改正する法律案
# 14341     北方    B  北方領土問題等の解決の促進のための特別措置に関する法律の一部を改正する法律案
# 14533     漁業    B          漁業権者等に対する特別措置に関する法律の一部を改正する法律案
# 15824     ＩＲ    B                                   ＩＲ整備法
# 15829    カジノ    B                                   カジノ法案
# 16000    カジノ    B                                    カジノ法
# 16289    カジノ    B                                   カジノ法案
# 16324    カジノ    B                                   カジノ法案
# 16555    カジノ    B                                   カジノ法案
# 16722    カジノ    B                                   カジノ法案
# 16777    カジノ    B                                   カジノ法案
# 16802    カジノ    B                                    カジノ法
# 16896    カジノ    B                                    カジノ法
# 16930     ＩＲ    B                                   ＩＲ整備法
# 17592     ＩＲ    B                                    ＩＲ法案
# 17847    カジノ    B                                   カジノ法案
# 17910    カジノ    B                                   カジノ法案
# 17950    カジノ    B                                   カジノ法案
# 18125    カジノ    B                                    カジノ法
# 18442     特定    B                          特定複合観光施設区域整備法案
# 18452     ＩＲ    B                                    ＩＲ法案
# 18609     ＩＲ    B                                   ＩＲ推進法
# 18660     整備    B                                    整備法案
# 19590     ＩＲ    B                                  ＩＲ整備法案
# 20206     ＩＲ    B                                    ＩＲ法案
# 20549     ＩＲ    B                                    ＩＲ法案
# 20774     風営    B                                     風営法
# 20966     ＩＲ    B                                    ＩＲ法案
# 21519     特定    B                          特定複合観光施設区域整備法案
# 21698     施設    B                                施設区域整備法案
# 21705    カジノ    B                                   カジノ法案
# 21723    カジノ    B                                   カジノ法案
# 21728     ＩＲ    B                                    ＩＲ法案
# 21775    カジノ    B                                   カジノ法案
# 21811    カジノ    B                                   カジノ法案
# 21841     ＩＲ    B                                   ＩＲ推進法
# 21897    カジノ    B                                   カジノ法案
# 22751    カジノ    B                                    カジノ法
# 22781    カジノ    B                                   カジノ法案
# 22966    カジノ    B                                    カジノ法
# 23267    カジノ    B                                    カジノ法
# 23449      Ｔ    B                                    ＴＰＰ法
# 23457     ＩＲ    B                                    ＩＲ法案
# 23603     ＩＲ    B                                  ＩＲ整備法案
# 24395     ＩＲ    B                                  ＩＲ整備法案
# 24478    カジノ    B                                   カジノ法案
# 24672     ＩＲ    B                                  ＩＲ整備法案
# 24857     ＩＲ    B                                   ＩＲ推進法
# 24941     ＩＲ    B                                  ＩＲ整備法案
# 24984     推進    B                                     推進法
# 26586     医療    B                                医療総合確保法案
# 29333     地方    B                                   地方自治法
# 29340     一括    B                                     一括法
# 31694     安全    B                                  安全保障法制
# 32689     安保    B                                    安保法制
# 33418     介護    B                             介護・医療総合確保法案
# 33507     医療    B                           医療法と介護保険法の改正案
# 47439     過労    B                             過労死等防止対策推進法
# 47513     過労    B                             過労死等防止対策推進法
# 47554     過労    B                             過労死等防止対策推進法
# 48516     過労    B                             過労死等防止対策推進法
# 48651     過労    B                             過労死等防止対策推進法
# 48984     労働    B                                   労働基準法
# 49038     過労    B                                  過労死促進法
# 49364     労働    B                                   労働基準法
# 51936     農協    B                                     農協法
# 54517     強化    B                                     強化法
# 55470     競争    B                                  競争力強化法
# 55846     農業    B                              農業競争力強化支援法
# 56242     農業    B                             農業競争力強化支援法案
# 57168     強化    B                                     強化法
# 71940   クリーン    B                                クリーンウッド法
# 71990   クリーン    B                                クリーンウッド法
# 72042   クリーン    B                                クリーンウッド法
# 72093   クリーン    B                                クリーンウッド法
# 72164     木材    B                     木材等の流通及び利用の促進に関する法律
# 72530   グリーン    B                                 グリーン購入法
# 77902    ＪＡＳ    B                                    ＪＡＳ法
# 86783     国家    B                             国家戦略特区法改正法案
# 88821     構造    B                    構造改革特別区域法の一部を改正する法律案
# 92861     農政    B                                 農政改革関連法
# 92879     農業    B                               農業版競争力強化法
# 96856     競争    B                                  競争力強化法
# 96877     農業    B                                農業競争力支援法
# 100398    国際    B                                   国際海洋法
# 105072    都市    B                               都市農業振興基本法
# 105915    農地    B                                     農地法
# 142883    安保    B                                    安保法制
# 143744    国民    B                                   国民投票法
# 143752    国民    B                                   国民投票法
# 143777    国民    B                                   国民投票法
# 145887    災害    B                                 災害対策基本法
# 145929    警察    B                                     警察法
# 145958    災害    B                                 災害対策基本法
# 148273    安保    B                                    安保法制
# 150914    放送    B                                     放送法
# 152721    特例    B                                   特例公債法
# 153317    財政    B                                     財政法
# 170096    政治    B                                 政治資金規正法
# 170491    政治    B                                 政治資金規正法
# 170925    安保    B                                    安保法制
# 170931    戦争    B                                     戦争法
# 170978    安保    B                                    安保法制
# 170981    戦争    B                                     戦争法
# 171034    安保    B                                    安保法制
# 171037    戦争    B                                     戦争法
# 171479    安保    B                                    安保法制
# 171482    戦争    B                                     戦争法
# 171516    平和    B                                  平和安全法制
# 171598    安保    B                                    安保法制
# 171601    戦争    B                                     戦争法
# 171613   ＰＫＯ    B                                    ＰＫＯ法
# 171617    国連    B                                 国連平和協力法
# 171864    戦争    B                                     戦争法
# 171908   ＰＫＯ    B                                    ＰＫＯ法
# 172857    武力    B                                   武力紛争法
# 172890    武力    B                                   武力紛争法
# 173234    改正    B                                  改正ＰＫＯ法
# 173569   ＰＫＯ    B                                    ＰＫＯ法
# 177805   ＰＫＯ    B                                    ＰＫＯ法
# 178192   ＰＫＯ    B                                    ＰＫＯ法
# 178330    改定    B                                  改定ＰＫＯ法
# 178484   ＰＫＯ    B                                    ＰＫＯ法
# 178553   ＰＫＯ    B                                    ＰＫＯ法
# 178665   ＰＫＯ    B                                    ＰＫＯ法
# 178728   ＰＫＯ    B                                    ＰＫＯ法
# 178779   ＰＫＯ    B                                    ＰＫＯ法
# 179708    改定    B                                  改定ＰＫＯ法
# 181208    安保    B                                    安保法制
# 181211    戦争    B                                     戦争法
# 181328    戦争    B                                     戦争法
# 184645    安保    B                                    安保法制
# 184648    戦争    B                                     戦争法
# 184709    安保    B                                    安保法制
# 184725    国際    B                                 国際平和支援法
# 185018    国際    B                                 国際平和支援法
# 185122    国際    B                                 国際平和支援法
# 185193    国際    B                                 国際平和支援法
# 187722    安全    B                                  安全保障法制
# 189562    戦争    B                                     戦争法
# 189685    国際    B                                 国際平和支援法
# 190138    安保    B                                    安保法制
# 190141    戦争    B                                     戦争法
# 190233    安保    B                                    安保法制
# 190236    戦争    B                                     戦争法
# 190261    戦争    B                                     戦争法
# 190321    戦争    B                                     戦争法
# 190387    戦争    B                                     戦争法
# 192270    安保    B                                    安保法案
# 199773     都    B                                      都法
# 201746    首都    B                                 首都機能移転法
# 204754    安保    B                                    安保法制
# 204951    改革    B                                   改革基本法
# 205077     員    B                                員制度改革基本法
#
#                   wikipediaタイトル  \
# 53                          NaN
# 78                          NaN
# 113                         NaN
# 635                         NaN
# 642                         NaN
# 656      特定複合観光施設区域の整備の推進に関する法律
# 1184     特定複合観光施設区域の整備の推進に関する法律
# 1194     特定複合観光施設区域の整備の推進に関する法律
# 2045                        NaN
# 2093     特定複合観光施設区域の整備の推進に関する法律
# 2437                        NaN
# 3420                        NaN
# 3427     特定複合観光施設区域の整備の推進に関する法律
# 4793     特定複合観光施設区域の整備の推進に関する法律
# 5195     特定複合観光施設区域の整備の推進に関する法律
# 5473     特定複合観光施設区域の整備の推進に関する法律
# 5707                        NaN
# 5720                        NaN
# 6332     特定複合観光施設区域の整備の推進に関する法律
# 6336                        NaN
# 7348                        NaN
# 7486     特定複合観光施設区域の整備の推進に関する法律
# 9224                        NaN
# 9616     特定複合観光施設区域の整備の推進に関する法律
# 9842                        NaN
# 10276                      貸金業法
# 10431                       NaN
# 10563    特定複合観光施設区域の整備の推進に関する法律
# 10746    特定複合観光施設区域の整備の推進に関する法律
# 11772                       NaN
# 12008                       NaN
# 12333                       NaN
# 14139                       NaN
# 14167                       NaN
# 14341                       NaN
# 14533                       NaN
# 15824                       NaN
# 15829    特定複合観光施設区域の整備の推進に関する法律
# 16000    特定複合観光施設区域の整備の推進に関する法律
# 16289    特定複合観光施設区域の整備の推進に関する法律
# 16324    特定複合観光施設区域の整備の推進に関する法律
# 16555    特定複合観光施設区域の整備の推進に関する法律
# 16722    特定複合観光施設区域の整備の推進に関する法律
# 16777    特定複合観光施設区域の整備の推進に関する法律
# 16802    特定複合観光施設区域の整備の推進に関する法律
# 16896    特定複合観光施設区域の整備の推進に関する法律
# 16930                       NaN
# 17592    特定複合観光施設区域の整備の推進に関する法律
# 17847    特定複合観光施設区域の整備の推進に関する法律
# 17910    特定複合観光施設区域の整備の推進に関する法律
# 17950    特定複合観光施設区域の整備の推進に関する法律
# 18125    特定複合観光施設区域の整備の推進に関する法律
# 18442                       NaN
# 18452    特定複合観光施設区域の整備の推進に関する法律
# 18609    特定複合観光施設区域の整備の推進に関する法律
# 18660                       NaN
# 19590                       NaN
# 20206    特定複合観光施設区域の整備の推進に関する法律
# 20549    特定複合観光施設区域の整備の推進に関する法律
# 20774   風俗営業等の規制及び業務の適正化等に関する法律
# 20966    特定複合観光施設区域の整備の推進に関する法律
# 21519                       NaN
# 21698                       NaN
# 21705    特定複合観光施設区域の整備の推進に関する法律
# 21723    特定複合観光施設区域の整備の推進に関する法律
# 21728    特定複合観光施設区域の整備の推進に関する法律
# 21775    特定複合観光施設区域の整備の推進に関する法律
# 21811    特定複合観光施設区域の整備の推進に関する法律
# 21841    特定複合観光施設区域の整備の推進に関する法律
# 21897    特定複合観光施設区域の整備の推進に関する法律
# 22751    特定複合観光施設区域の整備の推進に関する法律
# 22781    特定複合観光施設区域の整備の推進に関する法律
# 22966    特定複合観光施設区域の整備の推進に関する法律
# 23267    特定複合観光施設区域の整備の推進に関する法律
# 23449                       NaN
# 23457    特定複合観光施設区域の整備の推進に関する法律
# 23603                       NaN
# 24395                       NaN
# 24478    特定複合観光施設区域の整備の推進に関する法律
# 24672                       NaN
# 24857    特定複合観光施設区域の整備の推進に関する法律
# 24941                       NaN
# 24984                       NaN
# 26586                       NaN
# 29333                     地方自治法
# 29340                       NaN
# 31694                    平和安全法制
# 32689                    平和安全法制
# 33418                       NaN
# 33507                       NaN
# 47439               過労死等防止対策推進法
# 47513               過労死等防止対策推進法
# 47554               過労死等防止対策推進法
# 48516               過労死等防止対策推進法
# 48651               過労死等防止対策推進法
# 48984                     労働基準法
# 49038                       NaN
# 49364                     労働基準法
# 51936                   農業協同組合法
# 54517                       NaN
# 55470                       NaN
# 55846                       NaN
# 56242                       NaN
# 57168                       NaN
# 71940                       NaN
# 71990                       NaN
# 72042                       NaN
# 72093                       NaN
# 72164                       NaN
# 72530   国等による環境物品等の調達の推進等に関する法律
# 77902           農林物資の規格化等に関する法律
# 86783                       NaN
# 88821                       NaN
# 92861                       NaN
# 92879                       NaN
# 96856                       NaN
# 96877                       NaN
# 100398                    国際海洋法
# 105072                      NaN
# 105915                      農地法
# 142883                   平和安全法制
# 143744         日本国憲法の改正手続に関する法律
# 143752         日本国憲法の改正手続に関する法律
# 143777         日本国憲法の改正手続に関する法律
# 145887                  災害対策基本法
# 145929                      警察法
# 145958                  災害対策基本法
# 148273                   平和安全法制
# 150914                      放送法
# 152721                    特例公債法
# 153317                      財政法
# 170096                  政治資金規正法
# 170491                  政治資金規正法
# 170925                   平和安全法制
# 170931                      NaN
# 170978                   平和安全法制
# 170981                      NaN
# 171034                   平和安全法制
# 171037                      NaN
# 171479                   平和安全法制
# 171482                      NaN
# 171516                   平和安全法制
# 171598                   平和安全法制
# 171601                      NaN
# 171613  国際連合平和維持活動等に対する協力に関する法律
# 171617                      NaN
# 171864                      NaN
# 171908  国際連合平和維持活動等に対する協力に関する法律
# 172857                    戦時国際法
# 172890                    戦時国際法
# 173234                      NaN
# 173569  国際連合平和維持活動等に対する協力に関する法律
# 177805  国際連合平和維持活動等に対する協力に関する法律
# 178192  国際連合平和維持活動等に対する協力に関する法律
# 178330                      NaN
# 178484  国際連合平和維持活動等に対する協力に関する法律
# 178553  国際連合平和維持活動等に対する協力に関する法律
# 178665  国際連合平和維持活動等に対する協力に関する法律
# 178728  国際連合平和維持活動等に対する協力に関する法律
# 178779  国際連合平和維持活動等に対する協力に関する法律
# 179708                      NaN
# 181208                   平和安全法制
# 181211                      NaN
# 181328                      NaN
# 184645                   平和安全法制
# 184648                      NaN
# 184709                   平和安全法制
# 184725                   平和安全法制
# 185018                   平和安全法制
# 185122                   平和安全法制
# 185193                   平和安全法制
# 187722                   平和安全法制
# 189562                      NaN
# 189685                   平和安全法制
# 190138                   平和安全法制
# 190141                      NaN
# 190233                   平和安全法制
# 190236                      NaN
# 190261                      NaN
# 190321                      NaN
# 190387                      NaN
# 192270                   平和安全法制
# 199773                      NaN
# 201746                      NaN
# 204754                   平和安全法制
# 204951                      NaN
# 205077                      NaN
#
#                                              wikipediaページ
# 53                                                    NaN
# 78                                                    NaN
# 113                                                   NaN
# 635                                                   NaN
# 642                                                   NaN
# 656     https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 1184    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 1194    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 2045                                                  NaN
# 2093    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 2437                                                  NaN
# 3420                                                  NaN
# 3427    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 4793    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 5195    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 5473    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 5707                                                  NaN
# 5720                                                  NaN
# 6332    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 6336                                                  NaN
# 7348                                                  NaN
# 7486    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 9224                                                  NaN
# 9616    https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 9842                                                  NaN
# 10276   https://ja.wikipedia.org/wiki/%E8%B2%B8%E9%87%...
# 10431                                                 NaN
# 10563   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 10746   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 11772                                                 NaN
# 12008                                                 NaN
# 12333                                                 NaN
# 14139                                                 NaN
# 14167                                                 NaN
# 14341                                                 NaN
# 14533                                                 NaN
# 15824                                                 NaN
# 15829   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16000   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16289   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16324   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16555   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16722   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16777   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16802   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16896   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 16930                                                 NaN
# 17592   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 17847   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 17910   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 17950   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 18125   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 18442                                                 NaN
# 18452   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 18609   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 18660                                                 NaN
# 19590                                                 NaN
# 20206   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 20549   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 20774   https://ja.wikipedia.org/wiki/%E9%A2%A8%E4%BF%...
# 20966   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21519                                                 NaN
# 21698                                                 NaN
# 21705   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21723   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21728   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21775   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21811   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21841   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 21897   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 22751   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 22781   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 22966   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 23267   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 23449                                                 NaN
# 23457   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 23603                                                 NaN
# 24395                                                 NaN
# 24478   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 24672                                                 NaN
# 24857   https://ja.wikipedia.org/wiki/%E7%89%B9%E5%AE%...
# 24941                                                 NaN
# 24984                                                 NaN
# 26586                                                 NaN
# 29333   https://ja.wikipedia.org/wiki/%E5%9C%B0%E6%96%...
# 29340                                                 NaN
# 31694   https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 32689   https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 33418                                                 NaN
# 33507                                                 NaN
# 47439   https://ja.wikipedia.org/wiki/%E9%81%8E%E5%8A%...
# 47513   https://ja.wikipedia.org/wiki/%E9%81%8E%E5%8A%...
# 47554   https://ja.wikipedia.org/wiki/%E9%81%8E%E5%8A%...
# 48516   https://ja.wikipedia.org/wiki/%E9%81%8E%E5%8A%...
# 48651   https://ja.wikipedia.org/wiki/%E9%81%8E%E5%8A%...
# 48984   https://ja.wikipedia.org/wiki/%E5%8A%B4%E5%83%...
# 49038                                                 NaN
# 49364   https://ja.wikipedia.org/wiki/%E5%8A%B4%E5%83%...
# 51936   https://ja.wikipedia.org/wiki/%E8%BE%B2%E6%A5%...
# 54517                                                 NaN
# 55470                                                 NaN
# 55846                                                 NaN
# 56242                                                 NaN
# 57168                                                 NaN
# 71940                                                 NaN
# 71990                                                 NaN
# 72042                                                 NaN
# 72093                                                 NaN
# 72164                                                 NaN
# 72530   https://ja.wikipedia.org/wiki/%E5%9B%BD%E7%AD%...
# 77902   https://ja.wikipedia.org/wiki/%E8%BE%B2%E6%9E%...
# 86783                                                 NaN
# 88821                                                 NaN
# 92861                                                 NaN
# 92879                                                 NaN
# 96856                                                 NaN
# 96877                                                 NaN
# 100398  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 105072                                                NaN
# 105915  https://ja.wikipedia.org/wiki/%E8%BE%B2%E5%9C%...
# 142883  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 143744  https://ja.wikipedia.org/wiki/%E6%97%A5%E6%9C%...
# 143752  https://ja.wikipedia.org/wiki/%E6%97%A5%E6%9C%...
# 143777  https://ja.wikipedia.org/wiki/%E6%97%A5%E6%9C%...
# 145887  https://ja.wikipedia.org/wiki/%E7%81%BD%E5%AE%...
# 145929  https://ja.wikipedia.org/wiki/%E8%AD%A6%E5%AF%...
# 145958  https://ja.wikipedia.org/wiki/%E7%81%BD%E5%AE%...
# 148273  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 150914  https://ja.wikipedia.org/wiki/%E6%94%BE%E9%80%...
# 152721  https://ja.wikipedia.org/wiki/%E7%89%B9%E4%BE%...
# 153317  https://ja.wikipedia.org/wiki/%E8%B2%A1%E6%94%...
# 170096  https://ja.wikipedia.org/wiki/%E6%94%BF%E6%B2%...
# 170491  https://ja.wikipedia.org/wiki/%E6%94%BF%E6%B2%...
# 170925  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 170931                                                NaN
# 170978  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 170981                                                NaN
# 171034  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 171037                                                NaN
# 171479  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 171482                                                NaN
# 171516  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 171598  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 171601                                                NaN
# 171613  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 171617                                                NaN
# 171864                                                NaN
# 171908  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 172857  https://ja.wikipedia.org/wiki/%E6%88%A6%E6%99%...
# 172890  https://ja.wikipedia.org/wiki/%E6%88%A6%E6%99%...
# 173234                                                NaN
# 173569  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 177805  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178192  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178330                                                NaN
# 178484  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178553  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178665  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178728  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 178779  https://ja.wikipedia.org/wiki/%E5%9B%BD%E9%9A%...
# 179708                                                NaN
# 181208  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 181211                                                NaN
# 181328                                                NaN
# 184645  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 184648                                                NaN
# 184709  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 184725  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 185018  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 185122  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 185193  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 187722  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 189562                                                NaN
# 189685  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 190138  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 190141                                                NaN
# 190233  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 190236                                                NaN
# 190261                                                NaN
# 190321                                                NaN
# 190387                                                NaN
# 192270  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 199773                                                NaN
# 201746                                                NaN
# 204754  https://ja.wikipedia.org/wiki/%E5%B9%B3%E5%92%...
# 204951                                                NaN
# 205077                                                NaN

# %%
len(df_test_result)
# Out:
# 209862

# %%
df_test = pd.read_table('../data/PoliInfo2-EntityLinking-FormalRun-v20200703/AnswerSheet/PoliInfo2-EntityLinking-JA-Formal-Test.tsv')

# %%
len(df_test)
# Out:
# 209862

# %%
df_test_result['形態素'] = df_test['形態素']

# %%
df_test_result['IOB2'] = df_test_result['IOB2'].replace('O', np.nan)

# %%
df_test_result.to_csv('../submission/submission.tsv', sep='\t', index=False)
